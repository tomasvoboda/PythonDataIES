# %%
import requests
import pandas as pd
import time

# %% [markdown]
# # Seminar - APIs and real-life coding

# %% [markdown]
# ## Task 1: Requesting API
# ### 1a. Create a function requesting data from sreality
#
# ```python
# base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page={}'.format(i)
#
# r = requests.get(base_url)
# d = r.json()
# ```
#
# * function should parametrize:
#     * `category_main_cb` - `{'flat':1, 'house':2, 'land':3 }`
#     * `category_type_cb` - `{'sell':1,'rent':2}`
#     * `locality_region_id` - `{'Praha':10,'Brno':14}`
#     * `page` parameter
# * use string inputs for `category_main_cb` and `category_type_cb`
# * test the validity of inputs
# * include try/except clause to handle errors
# * function should return JSON data in python types
# * do not forget to sleep each request at least 0.5s

# %%
def request_sreality(page, category_main='flat', category_type='sell', locality_region='Praha'):
    
    time.sleep(0.5)

    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1,'rent':2}
    region_mapping = {'Praha':10, 'Brno':14}
    
    if category_main not in category_mains:
        raise Exception(f'Unknown category main {category_main}')
    
    if category_type not in category_types:
        raise Exception(f'Unknown category type {category_type}')
    
    if locality_region not in region_mapping:
        raise Exception(f'Unknown locality region {locality_region}')
    
    url_template = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main_cb}&category_type_cb={category_type_cb}&locality_region_id={locality_region_id}&per_page60&page={page}'
    
    try:
        url = url_template.format(
            category_main_cb=category_mains[category_main],
            category_type_cb=category_types[category_type],
            locality_region_id=region_mapping[locality_region],
            page=page
        )

        r = requests.get(url)

        return r.json()
    except Exception as e:
        print(e)
d = request_sreality(0)
d.keys()
# Out:
# dict_keys(['meta_description', 'result_size', '_embedded', 'filterLabels', 'title', 'filter', '_links', 'locality', 'locality_dativ', 'logged_in', 'per_page', 'category_instrumental', 'page', 'filterLabels2'])

# %% [markdown]
# ### 1b. Create a function converting sreality json data into pandas dataframe

# %%
def sreality_json_to_df(sreality_data):
    return pd.DataFrame(sreality_data['_embedded']['estates'])
sreality_json_to_df(d)
# Out:
#                                        labelsReleased  has_panorama  \
# 0                            [[partly_furnished], []]             0
# 1                           [[not_furnished], [shop]]             0
# 2   [[after_reconstruction, partly_furnished], [me...             0
# 3                       [[furnished], [metro, medic]]             0
# 4                                            [[], []]             0
# 5                                            [[], []]             0
# 6                                            [[], []]             0
# 7                                            [[], []]             0
# 8                                            [[], []]             0
# 9                                            [[], []]             0
# 10                              [[not_furnished], []]             0
# 11                                           [[], []]             0
# 12                                           [[], []]             0
# 13                                           [[], []]             0
# 14                                           [[], []]             0
# 15                                  [[furnished], []]             0
# 16                                  [[furnished], []]             0
# 17                          [[not_furnished], [shop]]             0
# 18                                           [[], []]             0
# 19                                  [[furnished], []]             0
# 20  [[after_reconstruction, partly_furnished], [sh...             0
#
#                                                labels  is_auction  \
# 0                                 [Částečně vybavený]       False
# 1                   [Nevybavený, Obchod 6 min. pěšky]       False
# 2   [Po rekonstrukci, Částečně vybavený, Lékař 9 m...       False
# 3   [Vybavený, Metro 7 min. pěšky, Lékař 8 min. pě...       False
# 4                                                  []       False
# 5                                                  []       False
# 6                                                  []       False
# 7                                                  []       False
# 8                                                  []       False
# 9                                                  []       False
# 10                                       [Nevybavený]       False
# 11                                                 []       False
# 12                                                 []       False
# 13                                                 []       False
# 14                                                 []       False
# 15                                         [Vybavený]       False
# 16                                         [Vybavený]       False
# 17                  [Nevybavený, Obchod 6 min. pěšky]       False
# 18                                                 []       False
# 19                                         [Vybavený]       False
# 20  [Po rekonstrukci, Částečně vybavený, Obchod 5 ...       False
#
#                                             labelsAll  \
# 0   [[personal, balcony, brick, parking_lots, part...
# 1   [[new_building, personal, brick, elevator, not...
# 2   [[personal, after_reconstruction, balcony, bri...
# 3   [[personal, balcony, brick, elevator, furnishe...
# 4   [[new_building, personal, terrace, cellar, ele...
# 5   [[personal, terrace, brick, cellar], [playgrou...
# 6   [[personal, brick, cellar, elevator], [playgro...
# 7   [[new_building, personal, terrace, brick, cell...
# 8   [[new_building, personal, balcony, terrace, br...
# 9   [[new_building, personal, terrace, brick, cell...
# 10  [[personal, balcony, brick, elevator, not_furn...
# 11  [[personal, balcony, brick, cellar, elevator],...
# 12  [[personal, brick, elevator], [small_shop, can...
# 13  [[personal, brick, elevator], [playground, sma...
# 14  [[personal, brick, elevator, parking_lots], [p...
# 15  [[new_building, personal, brick, cellar, parki...
# 16  [[new_building, personal, balcony, brick, cell...
# 17  [[personal, balcony, terrace, brick, elevator,...
# 18  [[personal, brick, elevator], [playground, sma...
# 19  [[personal, balcony, brick, cellar, elevator, ...
# 20  [[personal, after_reconstruction, balcony, bri...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 1   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 2   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  1
# 3   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 4   {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 5   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 6   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 7   {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 8   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 9   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 10  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 11  {'category_main_cb': 1, 'category_sub_cb': 10,...                  0
# 12  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 13  {'category_main_cb': 1, 'category_sub_cb': 9, ...                  0
# 14  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 15  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 16  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 17  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 18  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 19  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 20  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
#
#     category  has_floor_plan  \
# 0          1               0
# 1          1               0
# 2          1               0
# 3          1               1
# 4          1               1
# 5          1               0
# 6          1               1
# 7          1               1
# 8          1               1
# 9          1               1
# 10         1               1
# 11         1               0
# 12         1               0
# 13         1               0
# 14         1               0
# 15         1               1
# 16         1               1
# 17         1               1
# 18         1               1
# 19         1               0
# 20         1               1
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...   355542092
# 1   {'favourite': {'is_favourite': False, '_links'...  ...  3094287948
# 2   {'favourite': {'is_favourite': False, '_links'...  ...  3466749516
# 3   {'favourite': {'is_favourite': False, '_links'...  ...  1720067660
# 4   {'favourite': {'is_favourite': False, '_links'...  ...  1888204620
# 5   {'favourite': {'is_favourite': False, '_links'...  ...  2678105932
# 6   {'favourite': {'is_favourite': False, '_links'...  ...   167024460
# 7   {'favourite': {'is_favourite': False, '_links'...  ...  2959854172
# 8   {'favourite': {'is_favourite': False, '_links'...  ...  3337562204
# 9   {'favourite': {'is_favourite': False, '_links'...  ...  3130050908
# 10  {'favourite': {'is_favourite': False, '_links'...  ...  2255587148
# 11  {'favourite': {'is_favourite': False, '_links'...  ...  1218758476
# 12  {'favourite': {'is_favourite': False, '_links'...  ...   761579340
# 13  {'favourite': {'is_favourite': False, '_links'...  ...  2405746508
# 14  {'favourite': {'is_favourite': False, '_links'...  ...  2087745100
# 15  {'favourite': {'is_favourite': False, '_links'...  ...  2518173516
# 16  {'favourite': {'is_favourite': False, '_links'...  ...  2262574156
# 17  {'favourite': {'is_favourite': False, '_links'...  ...   886064972
# 18  {'favourite': {'is_favourite': False, '_links'...  ...  2113250380
# 19  {'favourite': {'is_favourite': False, '_links'...  ...  3814892620
# 20  {'favourite': {'is_favourite': False, '_links'...  ...  1363081036
#
#    attractive_offer     price  \
# 0                 0   2884000
# 1                 0   4335000
# 2                 0   7392000
# 3                 0   9710000
# 4                 0   7803000
# 5                 0  10398000
# 6                 0   5144000
# 7                 0  10161000
# 8                 0  12044000
# 9                 0  11425000
# 10                0  11554000
# 11                0  11271000
# 12                0   7225000
# 13                0   4913000
# 14                0   4970000
# 15                0   9248000
# 16                0   7889000
# 17                0   8664000
# 18                0   4618000
# 19                0   5491000
# 20                0  10115000
#
#                                             price_czk  \
# 0   {'value_raw': 2884000, 'unit': '', 'name': 'Ce...
# 1   {'value_raw': 4335000, 'unit': '', 'name': 'Ce...
# 2   {'value_raw': 7392000, 'unit': '', 'name': 'Ce...
# 3   {'value_raw': 9710000, 'unit': '', 'name': 'Ce...
# 4   {'value_raw': 7803000, 'unit': '', 'name': 'Ce...
# 5   {'value_raw': 10398000, 'unit': '', 'name': 'C...
# 6   {'value_raw': 5144000, 'unit': '', 'name': 'Ce...
# 7   {'value_raw': 10161000, 'unit': '', 'name': 'C...
# 8   {'value_raw': 12044000, 'unit': '', 'name': 'C...
# 9   {'value_raw': 11425000, 'unit': '', 'name': 'C...
# 10  {'value_raw': 11554000, 'unit': '', 'name': 'C...
# 11  {'value_raw': 11271000, 'unit': '', 'name': 'C...
# 12  {'value_raw': 7225000, 'unit': '', 'name': 'Ce...
# 13  {'value_raw': 4913000, 'unit': '', 'name': 'Ce...
# 14  {'value_raw': 4970000, 'unit': '', 'name': 'Ce...
# 15  {'value_raw': 9248000, 'unit': '', 'name': 'Ce...
# 16  {'value_raw': 7889000, 'unit': '', 'name': 'Ce...
# 17  {'value_raw': 8664000, 'unit': '', 'name': 'Ce...
# 18  {'value_raw': 4618000, 'unit': '', 'name': 'Ce...
# 19  {'value_raw': 5491000, 'unit': '', 'name': 'Ce...
# 20  {'value_raw': 10115000, 'unit': '', 'name': 'C...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 5   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 6   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 7   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 8   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 9   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 10  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 11  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 12  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 13  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 14  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 15  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 16  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...   True
# 17  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 18  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 19  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 20  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                        name  region_tip  \
# 0    Prodej bytu 2+kk 26 m²     2455736
# 1    Prodej bytu 2+kk 40 m²           0
# 2     Prodej bytu 3+1 62 m²           0
# 3     Prodej bytu 3+1 53 m²           0
# 4    Prodej bytu 3+kk 64 m²           0
# 5    Prodej bytu 4+kk 90 m²           0
# 6    Prodej bytu 2+kk 32 m²           0
# 7    Prodej bytu 3+kk 74 m²           0
# 8    Prodej bytu 4+kk 89 m²           0
# 9    Prodej bytu 4+kk 82 m²           0
# 10   Prodej bytu 4+kk 63 m²           0
# 11  Prodej bytu 5+kk 106 m²           0
# 12   Prodej bytu 3+kk 55 m²           0
# 13    Prodej bytu 4+1 49 m²           0
# 14   Prodej bytu 2+kk 31 m²           0
# 15   Prodej bytu 4+kk 60 m²           0
# 16   Prodej bytu 3+kk 60 m²           0
# 17   Prodej bytu 3+kk 57 m²           0
# 18   Prodej bytu 2+kk 28 m²           0
# 19   Prodej bytu 2+kk 35 m²           0
# 20   Prodej bytu 3+kk 58 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 50.07168497536439, 'lon': 14.511453024...               False
# 1   {'lat': 50.0704639753644, 'lon': 14.3405140246...               False
# 2   {'lat': 50.096899975364394, 'lon': 14.43855502...               False
# 3   {'lat': 50.0659359753644, 'lon': 14.4397380246...               False
# 4   {'lat': 50.082518975364394, 'lon': 14.48899802...               False
# 5   {'lat': 50.10459797536439, 'lon': 14.384456024...               False
# 6   {'lat': 50.068030975364394, 'lon': 14.46167902...               False
# 7   {'lat': 50.08014197536439, 'lon': 14.339171024...               False
# 8   {'lat': 50.08014197536439, 'lon': 14.339171024...               False
# 9   {'lat': 50.08014197536439, 'lon': 14.339171024...               False
# 10  {'lat': 50.08859597536439, 'lon': 14.463676024...               False
# 11  {'lat': 50.10177497536439, 'lon': 14.398773024...               False
# 12  {'lat': 50.0806459753644, 'lon': 14.4501840246...               False
# 13  {'lat': 50.0806459753644, 'lon': 14.4501840246...               False
# 14  {'lat': 50.081572975364395, 'lon': 14.46288402...               False
# 15  {'lat': 50.048197975364396, 'lon': 14.36211702...               False
# 16  {'lat': 50.01132897536439, 'lon': 14.407090024...               False
# 17  {'lat': 50.07809797536439, 'lon': 14.435949024...               False
# 18  {'lat': 50.0706889753644, 'lon': 14.4584660246...               False
# 19  {'lat': 50.08403697536439, 'lon': 14.482468024...               False
# 20  {'lat': 50.071432975364395, 'lon': 14.45299902...               False
#
# [21 rows x 27 columns]

# %% [markdown]
# ### 1c. link function `1b` into function `1a`

# %%
def request_sreality(page, category_main='flat', category_type='sell', locality_region='Praha'):
    
    time.sleep(0.5)

    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1,'rent':2}
    region_mapping = {'Praha':10, 'Brno':14}
    
    if category_main not in category_mains:
        raise Exception(f'Unknown category main {category_main}')
    
    if category_type not in category_types:
        raise Exception(f'Unknown category type {category_type}')
    
    if locality_region not in region_mapping:
        raise Exception(f'Unknown locality region {locality_region}')
    
    url_template = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main_cb}&category_type_cb={category_type_cb}&locality_region_id={locality_region_id}&per_page60&page={page}'
    
    try:
        url = url_template.format(
            category_main_cb=category_mains[category_main],
            category_type_cb=category_types[category_type],
            locality_region_id=region_mapping[locality_region],
            page=page
        )

        r = requests.get(url)

        return sreality_json_to_df(r.json())    
    except Exception as e:
        print(e)
d = request_sreality(0)
d.keys()
# Out:
# Index(['labelsReleased', 'has_panorama', 'labels', 'is_auction', 'labelsAll',
#        'seo', 'exclusively_at_rk', 'category', 'has_floor_plan', '_embedded',
#        'paid_logo', 'locality', 'has_video', 'advert_images_count', 'new',
#        'auctionPrice', 'type', 'hash_id', 'attractive_offer', 'price',
#        'price_czk', '_links', 'rus', 'name', 'region_tip', 'gps',
#        'has_matterport_url'],
#       dtype='object')

# %% [markdown]
# ### 1c. Combining multiple requests into single df
#
# * Function should parametrize:
#     * `start_page` and `end_page`
#     * request parameters
# * construct a list of individual request dfs
# * then feed it into `pd.concat` function

# %%
def multiple_sreality_requests(start_page,end_page,category_main='flat', category_type='sell', locality_region='Praha'):
    return pd.concat([
        request_sreality(i, category_main=category_main, category_type=category_type, locality_region=locality_region) 
        for i in range(start_page,end_page+1)
    ])

raw = multiple_sreality_requests(0,4)
raw.head()
# Out:
#                                       labelsReleased  has_panorama  \
# 0    [[balcony, parking_lots, partly_furnished], []]             0
# 1                                [[], [metro, shop]]             0
# 2  [[after_reconstruction, balcony, not_furnished...             0
# 3                                [[], [post_office]]             0
# 4           [[terrace, parking_lots], [metro, shop]]             0
#
#                                               labels  is_auction  \
# 0             [Balkon, Parkování, Částečně vybavený]       False
# 1          [Metro 4 min. pěšky, Obchod 1 min. pěšky]       False
# 2  [Po rekonstrukci, Balkon, Nevybavený, Pošta 3 ...       False
# 3                               [Pošta 6 min. pěšky]       False
# 4  [Terasa, Parkování, Metro 4 min. pěšky, Obchod...       False
#
#                                            labelsAll  \
# 0  [[personal, balcony, brick, parking_lots, part...
# 1  [[personal, brick], [candy_shop, vet, tavern, ...
# 2  [[personal, after_reconstruction, balcony, bri...
# 3  [[personal, brick, cellar, elevator], [candy_s...
# 4  [[personal, terrace, brick, parking_lots, gara...
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 1  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 2  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 3  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 4  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
#
#    category  has_floor_plan  \
# 0         1               0
# 1         1               1
# 2         1               1
# 3         1               1
# 4         1               1
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...   355542092
# 1  {'favourite': {'is_favourite': False, '_links'...  ...   930572892
# 2  {'favourite': {'is_favourite': False, '_links'...  ...  2523454812
# 3  {'favourite': {'is_favourite': False, '_links'...  ...  3142851420
# 4  {'favourite': {'is_favourite': False, '_links'...  ...   971737948
#
#   attractive_offer     price  \
# 0                0   2884000
# 1                0   3872000
# 2                0  16762000
# 3                0  10398000
# 4                0   7918000
#
#                                            price_czk  \
# 0  {'value_raw': 2884000, 'unit': '', 'name': 'Ce...
# 1  {'value_raw': 3872000, 'unit': '', 'name': 'Ce...
# 2  {'value_raw': 16762000, 'unit': '', 'name': 'C...
# 3  {'value_raw': 10398000, 'unit': '', 'name': 'C...
# 4  {'value_raw': 7918000, 'unit': '', 'name': 'Ce...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                      name  region_tip  \
# 0  Prodej bytu 2+kk 26 m²     2455736
# 1  Prodej bytu 1+kk 21 m²           0
# 2  Prodej bytu 4+kk 93 m²           0
# 3  Prodej bytu 4+kk 84 m²           0
# 4  Prodej bytu 2+kk 49 m²           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.07168497536439, 'lon': 14.511453024...               False
# 1  {'lat': 50.0752789753644, 'lon': 14.4282010246...               False
# 2  {'lat': 50.0953589753644, 'lon': 14.4059020246...               False
# 3  {'lat': 50.07188697536439, 'lon': 14.408973024...               False
# 4  {'lat': 50.084898975364396, 'lon': 14.44090202...               False
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Task 2: Cleaning data
#
# ### 2a. Filter columns
# * filter only columns: `['locality', 'price', 'name', 'gps','hash_id','labelsAll','exclusively_at_rk']`
# * use `.copy()` to avoid `SettingWithCopyWarning` later

# %%
clean = raw[['locality', 'price', 'name', 'gps','hash_id','labelsAll','exclusively_at_rk']].copy()
clean.head()
# Out:
#                locality     price                    name  \
# 0  Praha 10 - Strašnice   2884000  Prodej bytu 2+kk 26 m²
# 1  Praha 1 - Nové Město   3872000  Prodej bytu 1+kk 21 m²
# 2     Praha 7 - Bubeneč  16762000  Prodej bytu 4+kk 93 m²
# 3     Praha 5 - Smíchov  10398000  Prodej bytu 4+kk 84 m²
# 4  Praha 1 - Nové Město   7918000  Prodej bytu 2+kk 49 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.07168497536439, 'lon': 14.511453024...   355542092
# 1  {'lat': 50.0752789753644, 'lon': 14.4282010246...   930572892
# 2  {'lat': 50.0953589753644, 'lon': 14.4059020246...  2523454812
# 3  {'lat': 50.07188697536439, 'lon': 14.408973024...  3142851420
# 4  {'lat': 50.084898975364396, 'lon': 14.44090202...   971737948
#
#                                            labelsAll  exclusively_at_rk
# 0  [[personal, balcony, brick, parking_lots, part...                  0
# 1  [[personal, brick], [candy_shop, vet, tavern, ...                  1
# 2  [[personal, after_reconstruction, balcony, bri...                  1
# 3  [[personal, brick, cellar, elevator], [candy_s...                  1
# 4  [[personal, terrace, brick, parking_lots, gara...                  0

# %% [markdown]
# ### 2b: GPS
# * Convert dictionary in `gps` column into two columns - `lat` and `lon`
# * use apply function on gps column
# * Note apply can return multiple columns

# %%
clean[['lat','lon']] = clean.gps.apply(lambda gps: pd.Series({'lat':gps['lat'], 'lon':gps['lon']}))

clean.head()
# Out:
#                locality     price                    name  \
# 0  Praha 10 - Strašnice   2884000  Prodej bytu 2+kk 26 m²
# 1  Praha 1 - Nové Město   3872000  Prodej bytu 1+kk 21 m²
# 2     Praha 7 - Bubeneč  16762000  Prodej bytu 4+kk 93 m²
# 3     Praha 5 - Smíchov  10398000  Prodej bytu 4+kk 84 m²
# 4  Praha 1 - Nové Město   7918000  Prodej bytu 2+kk 49 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.07168497536439, 'lon': 14.511453024...   355542092
# 1  {'lat': 50.0752789753644, 'lon': 14.4282010246...   930572892
# 2  {'lat': 50.0953589753644, 'lon': 14.4059020246...  2523454812
# 3  {'lat': 50.07188697536439, 'lon': 14.408973024...  3142851420
# 4  {'lat': 50.084898975364396, 'lon': 14.44090202...   971737948
#
#                                            labelsAll  exclusively_at_rk  \
# 0  [[personal, balcony, brick, parking_lots, part...                  0
# 1  [[personal, brick], [candy_shop, vet, tavern, ...                  1
# 2  [[personal, after_reconstruction, balcony, bri...                  1
# 3  [[personal, brick, cellar, elevator], [candy_s...                  1
# 4  [[personal, terrace, brick, parking_lots, gara...                  0
#
#          lat        lon
# 0  50.071685  14.511453
# 1  50.075279  14.428201
# 2  50.095359  14.405902
# 3  50.071887  14.408973
# 4  50.084899  14.440902

# %% [markdown]
# ### 2b. Get flat type from name
# * Name is always represented by string `Prodej bytu [type of flat] [Area] m^2`
# * try picking third word in string
# * check meaningfulness using `.value_counts()`

# %%
clean['flat_type'] = clean.name.apply(lambda nm: nm.split()[2])
clean
# Out:
#                  locality     price                                name  \
# 0    Praha 10 - Strašnice   2884000              Prodej bytu 2+kk 26 m²
# 1    Praha 1 - Nové Město   3872000              Prodej bytu 1+kk 21 m²
# 2       Praha 7 - Bubeneč  16762000              Prodej bytu 4+kk 93 m²
# 3       Praha 5 - Smíchov  10398000              Prodej bytu 4+kk 84 m²
# 4    Praha 1 - Nové Město   7918000              Prodej bytu 2+kk 49 m²
# ..                    ...       ...                                 ...
# 16      Praha 6 - Dejvice  14739000              Prodej bytu 4+kk 65 m²
# 17  Praha 1 - Staré Město   9594000              Prodej bytu 1+kk 36 m²
# 18   Praha 1 - Nové Město   3236000  Prodej bytu 1+kk 12 m² (Podkrovní)
# 19      Praha 5 - Smíchov  12716000             Prodej bytu 5+kk 108 m²
# 20   Praha 7 - Holešovice  11502000              Prodej bytu 3+kk 68 m²
#
#                                                   gps     hash_id  \
# 0   {'lat': 50.07168497536439, 'lon': 14.511453024...   355542092
# 1   {'lat': 50.0752789753644, 'lon': 14.4282010246...   930572892
# 2   {'lat': 50.0953589753644, 'lon': 14.4059020246...  2523454812
# 3   {'lat': 50.07188697536439, 'lon': 14.408973024...  3142851420
# 4   {'lat': 50.084898975364396, 'lon': 14.44090202...   971737948
# ..                                                ...         ...
# 16  {'lat': 50.10306097536439, 'lon': 14.383173024...   470955084
# 17  {'lat': 50.078772975364394, 'lon': 14.42356202...   836777036
# 18  {'lat': 50.0794559753644, 'lon': 14.4335560246...  1015297100
# 19  {'lat': 50.06103797536439, 'lon': 14.402338024...   614282316
# 20  {'lat': 50.0984379753644, 'lon': 14.4644720246...   701813836
#
#                                             labelsAll  exclusively_at_rk  \
# 0   [[personal, balcony, brick, parking_lots, part...                  0
# 1   [[personal, brick], [candy_shop, vet, tavern, ...                  1
# 2   [[personal, after_reconstruction, balcony, bri...                  1
# 3   [[personal, brick, cellar, elevator], [candy_s...                  1
# 4   [[personal, terrace, brick, parking_lots, gara...                  0
# ..                                                ...                ...
# 16  [[personal, balcony, brick, cellar, parking_lo...                  1
# 17  [[personal, brick, cellar, elevator, partly_fu...                  0
# 18  [[personal, brick, cellar, elevator, not_furni...                  1
# 19  [[personal, terrace, brick, cellar], [playgrou...                  0
# 20  [[new_building, personal, terrace, elevator, p...                  1
#
#           lat        lon flat_type
# 0   50.071685  14.511453      2+kk
# 1   50.075279  14.428201      1+kk
# 2   50.095359  14.405902      4+kk
# 3   50.071887  14.408973      4+kk
# 4   50.084899  14.440902      2+kk
# ..        ...        ...       ...
# 16  50.103061  14.383173      4+kk
# 17  50.078773  14.423562      1+kk
# 18  50.079456  14.433556      1+kk
# 19  50.061038  14.402338      5+kk
# 20  50.098438  14.464472      3+kk
#
# [105 rows x 10 columns]

# %% [markdown]
# ### 2c. Get area from name
# * Naive: select the word before last word
# * Then try navigating using the index of `'m²'`
# * if this also fail, then you will need to use regex

# %%
def name_to_area(nm):
    splitted= nm.split()
    
    m2_idx = splitted.index('m²')
    
    return int(splitted[m2_idx-1])

clean['area'] = clean.name.apply(name_to_area)
clean
# Out:
#                  locality     price                                name  \
# 0    Praha 10 - Strašnice   2884000              Prodej bytu 2+kk 26 m²
# 1    Praha 1 - Nové Město   3872000              Prodej bytu 1+kk 21 m²
# 2       Praha 7 - Bubeneč  16762000              Prodej bytu 4+kk 93 m²
# 3       Praha 5 - Smíchov  10398000              Prodej bytu 4+kk 84 m²
# 4    Praha 1 - Nové Město   7918000              Prodej bytu 2+kk 49 m²
# ..                    ...       ...                                 ...
# 16      Praha 6 - Dejvice  14739000              Prodej bytu 4+kk 65 m²
# 17  Praha 1 - Staré Město   9594000              Prodej bytu 1+kk 36 m²
# 18   Praha 1 - Nové Město   3236000  Prodej bytu 1+kk 12 m² (Podkrovní)
# 19      Praha 5 - Smíchov  12716000             Prodej bytu 5+kk 108 m²
# 20   Praha 7 - Holešovice  11502000              Prodej bytu 3+kk 68 m²
#
#                                                   gps     hash_id  \
# 0   {'lat': 50.07168497536439, 'lon': 14.511453024...   355542092
# 1   {'lat': 50.0752789753644, 'lon': 14.4282010246...   930572892
# 2   {'lat': 50.0953589753644, 'lon': 14.4059020246...  2523454812
# 3   {'lat': 50.07188697536439, 'lon': 14.408973024...  3142851420
# 4   {'lat': 50.084898975364396, 'lon': 14.44090202...   971737948
# ..                                                ...         ...
# 16  {'lat': 50.10306097536439, 'lon': 14.383173024...   470955084
# 17  {'lat': 50.078772975364394, 'lon': 14.42356202...   836777036
# 18  {'lat': 50.0794559753644, 'lon': 14.4335560246...  1015297100
# 19  {'lat': 50.06103797536439, 'lon': 14.402338024...   614282316
# 20  {'lat': 50.0984379753644, 'lon': 14.4644720246...   701813836
#
#                                             labelsAll  exclusively_at_rk  \
# 0   [[personal, balcony, brick, parking_lots, part...                  0
# 1   [[personal, brick], [candy_shop, vet, tavern, ...                  1
# 2   [[personal, after_reconstruction, balcony, bri...                  1
# 3   [[personal, brick, cellar, elevator], [candy_s...                  1
# 4   [[personal, terrace, brick, parking_lots, gara...                  0
# ..                                                ...                ...
# 16  [[personal, balcony, brick, cellar, parking_lo...                  1
# 17  [[personal, brick, cellar, elevator, partly_fu...                  0
# 18  [[personal, brick, cellar, elevator, not_furni...                  1
# 19  [[personal, terrace, brick, cellar], [playgrou...                  0
# 20  [[new_building, personal, terrace, elevator, p...                  1
#
#           lat        lon flat_type  area
# 0   50.071685  14.511453      2+kk    26
# 1   50.075279  14.428201      1+kk    21
# 2   50.095359  14.405902      4+kk    93
# 3   50.071887  14.408973      4+kk    84
# 4   50.084899  14.440902      2+kk    49
# ..        ...        ...       ...   ...
# 16  50.103061  14.383173      4+kk    65
# 17  50.078773  14.423562      1+kk    36
# 18  50.079456  14.433556      1+kk    12
# 19  50.061038  14.402338      5+kk   108
# 20  50.098438  14.464472      3+kk    68
#
# [105 rows x 11 columns]

# %% [markdown]
# ## Task 3 (Homework): Convert column`labelsAll` into boolean variables
#
# ### Task 3a. Get all possible label names
# * deal with nested-list structure
# * Hint: try sum the whole column to get a nested list of lists.
# * Then flatten the nested list (2D to 1D)
# * Finally keep only unique elements

# %%
possible_labels = list(set([item for sublist in raw.labelsAll.sum() for item in sublist]))
possible_labels
# Out:
# ['after_reconstruction',
#  'new_building',
#  'cellar',
#  'candy_shop',
#  'sports',
#  'drugstore',
#  'collective',
#  'elevator',
#  'playground',
#  'kindergarten',
#  'metro',
#  'loggia',
#  'sightseeing',
#  'movies',
#  'school',
#  'balcony',
#  'in_construction',
#  'brick',
#  'natural_attraction',
#  'not_furnished',
#  'bus_public_transport',
#  'small_shop',
#  'restaurant',
#  'panel',
#  'tavern',
#  'post_office',
#  'vet',
#  'atm',
#  'garage',
#  'furnished',
#  'terrace',
#  'shop',
#  'partly_furnished',
#  'medic',
#  'theater',
#  'parking_lots',
#  'train',
#  'tram',
#  'personal']

# %% [markdown]
# ### 4b. Test existence of label `cellar` for offers
# * again deal with nested list of list structure
# * write generic function `test_existence_of_label(offer_labels,label)`

# %%
def test_existence_of_label(offer_labels,label):
    return label in [item for sublist in offer_labels for item in sublist]
raw.labelsAll.apply(lambda offer_labels: test_existence_of_label(offer_labels, 'cellar'))
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# Name: labelsAll, Length: 105, dtype: bool

# %% [markdown]
# ### 4c. Test existence of all possible labels
# * use apply returning series with all labels

# %%
def existence_of_all_labels(offer_labels, possible_labels):
    return pd.Series({
        label:test_existence_of_label(offer_labels,label)
        for label in possible_labels
    })

raw.labelsAll.apply(lambda offer_labels: existence_of_all_labels(offer_labels, possible_labels))
# Out:
#     after_reconstruction  new_building  cellar  candy_shop  sports  drugstore  \
# 0                  False          True    True        True    True       True
# 1                   True         False   False        True    True       True
# 2                  False         False   False        True    True       True
# 3                  False          True    True        True    True       True
# 4                  False         False   False        True    True       True
# ..                   ...           ...     ...         ...     ...        ...
# 16                 False          True    True        True    True       True
# 17                 False          True    True        True    True       True
# 18                 False         False    True        True    True       True
# 19                 False          True    True        True    True       True
# 20                 False         False    True        True    True       True
#
#     collective  elevator  playground  kindergarten  ...  furnished  terrace  \
# 0        False      True        True          True  ...      False    False
# 1        False      True        True          True  ...       True    False
# 2        False     False        True          True  ...       True    False
# 3        False     False        True          True  ...       True     True
# 4        False     False        True          True  ...      False    False
# ..         ...       ...         ...           ...  ...        ...      ...
# 16       False      True        True          True  ...       True     True
# 17       False      True        True          True  ...       True    False
# 18       False      True        True          True  ...       True    False
# 19       False      True        True          True  ...       True     True
# 20       False      True        True          True  ...      False     True
#
#     shop  partly_furnished  medic  theater  parking_lots  train  tram  \
# 0   True             False   True     True          True   True  True
# 1   True             False   True     True         False   True  True
# 2   True             False   True     True         False   True  True
# 3   True             False   True     True         False   True  True
# 4   True             False   True     True         False   True  True
# ..   ...               ...    ...      ...           ...    ...   ...
# 16  True             False   True     True          True   True  True
# 17  True             False   True     True          True   True  True
# 18  True             False   True     True         False   True  True
# 19  True             False   True     True          True   True  True
# 20  True              True   True     True         False   True  True
#
#     personal
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ..       ...
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
#
# [105 rows x 39 columns]
